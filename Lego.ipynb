# %%
import pandas as pd

# %%
ds = pd.read_csv('lego_sets.csv')
ds
# Out:
#                set_id                     name  year                theme  \
# 0                 1-8          Small house set  1970            Minitalia
# 1                 2-8         Medium house set  1970            Minitalia
# 2                 3-6         Medium house set  1970            Minitalia
# 3                 4-4          Large house set  1970            Minitalia
# 4                 4-6  Mini House and Vehicles  1970            Samsonite
# ...               ...                      ...   ...                  ...
# 18452       SHUTTLE-1            Space Shuttle  2022          Promotional
# 18453       SLSDUCK-1                 SLS Duck  2022          Promotional
# 18454    SUMMERWAVE-1              Summer Wave  2022          Promotional
# 18455  TRUSPIDERMAN-1               Spider-Man  2022  Marvel Super Heroes
# 18456          YOTT-1                    Tiger  2022        Miscellaneous
#
#                 subtheme     themeGroup category  pieces  minifigs  \
# ...

# %%
ds.info
# Out:
# <bound method DataFrame.info of                set_id                     name  year                theme  \
# 0                 1-8          Small house set  1970            Minitalia
# 1                 2-8         Medium house set  1970            Minitalia
# 2                 3-6         Medium house set  1970            Minitalia
# 3                 4-4          Large house set  1970            Minitalia
# 4                 4-6  Mini House and Vehicles  1970            Samsonite
# ...               ...                      ...   ...                  ...
# 18452       SHUTTLE-1            Space Shuttle  2022          Promotional
# 18453       SLSDUCK-1                 SLS Duck  2022          Promotional
# 18454    SUMMERWAVE-1              Summer Wave  2022          Promotional
# 18455  TRUSPIDERMAN-1               Spider-Man  2022  Marvel Super Heroes
# 18456          YOTT-1                    Tiger  2022        Miscellaneous
#
# ...

# %%
ds.shape
# Out:
# (18457, 14)

# %%
df = ds.dropna()

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#        set_id                     name  year      theme    subtheme  \
# 6107   7236-1               Police Car  2005       City      Police
# 6254  10144-1              Sandcrawler  2005  Star Wars  Episode IV
# 6407   4962-1                 Baby Zoo  2006      Duplo  LEGO Ville
# 6445   6209-1                  Slave I  2006  Star Wars   Episode V
# 6447   6211-1  Imperial Star Destroyer  2006  Star Wars  Episode IV
#
#       themeGroup category  pieces  minifigs  agerange_min  US_retailPrice  \
# 6107  Modern day   Normal    59.0       1.0           5.0            5.99
# 6254    Licensed   Normal  1669.0      11.0          12.0          139.99
# 6407  Pre-school   Normal    18.0       1.0           2.0            9.99
# 6445    Licensed   Normal   537.0       5.0           8.0           49.99
# 6447    Licensed   Normal  1367.0       9.0           9.0           99.99
#
#                             bricksetURL  \
# 6107   https://brickset.com/sets/7236-1
# ...

# %%
df.tail()
# Out:
#         set_id                         name  year       theme  \
# 18025  80037-1           Dragon of the East  2022  Monkie Kid
# 18026  80038-1        Monkie Kid's Team Van  2022  Monkie Kid
# 18027  80039-1          The Heavenly Realms  2022  Monkie Kid
# 18028  80108-1    Lunar New Year Traditions  2022    Seasonal
# 18029  80109-1  Lunar New Year Ice Festival  2022    Seasonal
#
#                             subtheme        themeGroup category  pieces  \
# 18025                       Season 3  Action/Adventure   Normal   880.0
# 18026                       Season 3  Action/Adventure   Normal  1406.0
# 18027                       Season 3  Action/Adventure   Normal  2433.0
# 18028  Chinese Traditional Festivals     Miscellaneous   Normal  1066.0
# 18029  Chinese Traditional Festivals     Miscellaneous   Normal  1519.0
#
#        minifigs  agerange_min  US_retailPrice  \
# 18025       4.0           8.0           79.99
# 18026       6.0           9.0          129.99
# ...

# %%
df
# Out:
#         set_id                         name  year       theme  \
# 6107    7236-1                   Police Car  2005        City
# 6254   10144-1                  Sandcrawler  2005   Star Wars
# 6407    4962-1                     Baby Zoo  2006       Duplo
# 6445    6209-1                      Slave I  2006   Star Wars
# 6447    6211-1      Imperial Star Destroyer  2006   Star Wars
# ...        ...                          ...   ...         ...
# 18025  80037-1           Dragon of the East  2022  Monkie Kid
# 18026  80038-1        Monkie Kid's Team Van  2022  Monkie Kid
# 18027  80039-1          The Heavenly Realms  2022  Monkie Kid
# 18028  80108-1    Lunar New Year Traditions  2022    Seasonal
# 18029  80109-1  Lunar New Year Ice Festival  2022    Seasonal
#
#                             subtheme        themeGroup category  pieces  \
# 6107                          Police        Modern day   Normal    59.0
# 6254                      Episode IV          Licensed   Normal  1669.0
# ...

# %% [markdown]
# # от 5 до 30 с ходом 5

# %%
df.iloc[5:30:5]
# Out:
#       set_id               name  year      theme    subtheme  \
# 6492  7700-1     Stealth Hunter  2006  Exo-Force    Original
# 6527  7890-1          Ambulance  2006       City     Medical
# 6539  7901-1  Airplane Mechanic  2006       City     Airport
# 6604  8893-1  Lava Chamber Gate  2006   Bionicle    Playsets
# 6853  4861-1        Police Boat  2007      Duplo  LEGO Ville
#
#             themeGroup category  pieces  minifigs  agerange_min  \
# 6492  Action/Adventure   Normal   164.0       1.0           7.0
# 6527        Modern day   Normal   118.0       1.0           5.0
# 6539        Modern day   Normal    26.0       1.0           5.0
# 6604      Constraction   Normal   373.0       8.0           7.0
# 6853        Pre-school   Normal    27.0       3.0           2.0
#
#       US_retailPrice                       bricksetURL  \
# 6492           14.99  https://brickset.com/sets/7700-1
# 6527            7.99  https://brickset.com/sets/7890-1
# ...

# %% [markdown]
# # строки с 6492 по 6604 столбцы от name до theme

# %%
df.loc[6492:6604, 'name':'theme']
# Out:
#                            name  year      theme
# 6492             Stealth Hunter  2006  Exo-Force
# 6499             Striking Venom  2006  Exo-Force
# 6523            Big Pirate Ship  2006      Duplo
# 6524                Pirate Ship  2006      Duplo
# 6525               Shark Attack  2006      Duplo
# 6527                  Ambulance  2006       City
# 6529                   Hospital  2006       City
# 6530            Passenger Plane  2006       City
# 6532                    Airport  2006       City
# 6535            Passenger Train  2006       City
# 6539          Airplane Mechanic  2006       City
# 6540               Doctor's Car  2006       City
# 6541          Rescue Helicopter  2006       City
# 6556  Race for the Mask of Life  2006   Bionicle
# 6570        Ferrari Finish Line  2006     Racers
# 6604          Lava Chamber Gate  2006   Bionicle

# %% [markdown]
# # Срез по значению

# %%
df[df['year'] == 2006]
# Out:
#        set_id                       name  year      theme  \
# 6407   4962-1                   Baby Zoo  2006      Duplo
# 6445   6209-1                    Slave I  2006  Star Wars
# 6447   6211-1    Imperial Star Destroyer  2006  Star Wars
# 6492   7700-1             Stealth Hunter  2006  Exo-Force
# 6499   7707-1             Striking Venom  2006  Exo-Force
# 6523   7880-1            Big Pirate Ship  2006      Duplo
# 6524   7881-1                Pirate Ship  2006      Duplo
# 6525   7882-1               Shark Attack  2006      Duplo
# 6527   7890-1                  Ambulance  2006       City
# 6529   7892-1                   Hospital  2006       City
# 6530   7893-1            Passenger Plane  2006       City
# 6532   7894-1                    Airport  2006       City
# 6535   7897-1            Passenger Train  2006       City
# 6539   7901-1          Airplane Mechanic  2006       City
# 6540   7902-1               Doctor's Car  2006       City
# ...

# %% [markdown]
# Столбцы subtheme и themeGroup

# %%
df[['subtheme', 'themeGroup']]
# Out:
#                             subtheme        themeGroup
# 6107                          Police        Modern day
# 6254                      Episode IV          Licensed
# 6407                      LEGO Ville        Pre-school
# 6445                       Episode V          Licensed
# 6447                      Episode IV          Licensed
# ...                              ...               ...
# 18025                       Season 3  Action/Adventure
# 18026                       Season 3  Action/Adventure
# 18027                       Season 3  Action/Adventure
# 18028  Chinese Traditional Festivals     Miscellaneous
# 18029  Chinese Traditional Festivals     Miscellaneous
#
# [2669 rows x 2 columns]

# %% [markdown]
# Значение в ячейке с индексом 6445 и столбцом theme

# %%
df.at[6445, 'theme']
# Out:
# 'Star Wars'

# %% [markdown]
# # Значение в ячейке с индексом 4 и столбцом 1

# %%
df.iat[4, 1]
# Out:
# 'Imperial Star Destroyer'

# %% [markdown]
# # Чтение строк по индексу 18029, 18028, 6107

# %%
df.loc[[18029, 18028, 6107]]
# Out:
#         set_id                         name  year     theme  \
# 18029  80109-1  Lunar New Year Ice Festival  2022  Seasonal
# 18028  80108-1    Lunar New Year Traditions  2022  Seasonal
# 6107    7236-1                   Police Car  2005      City
#
#                             subtheme     themeGroup category  pieces  \
# 18029  Chinese Traditional Festivals  Miscellaneous   Normal  1519.0
# 18028  Chinese Traditional Festivals  Miscellaneous   Normal  1066.0
# 6107                          Police     Modern day   Normal    59.0
#
#        minifigs  agerange_min  US_retailPrice  \
# 18029      13.0           8.0          119.99
# 18028      12.0           8.0           79.99
# 6107        1.0           5.0            5.99
#
#                              bricksetURL  \
# 18029  https://brickset.com/sets/80109-1
# 18028  https://brickset.com/sets/80108-1
# 6107    https://brickset.com/sets/7236-1
#
#                                             thumbnailURL  \
# ...

# %% [markdown]
# Строка с индексом 18029

# %%
df.xs(18029)
# Out:
# set_id                                                      80109-1
# name                                    Lunar New Year Ice Festival
# year                                                           2022
# theme                                                      Seasonal
# subtheme                              Chinese Traditional Festivals
# themeGroup                                            Miscellaneous
# category                                                     Normal
# pieces                                                       1519.0
# minifigs                                                       13.0
# agerange_min                                                    8.0
# US_retailPrice                                               119.99
# bricksetURL                       https://brickset.com/sets/80109-1
# thumbnailURL      https://images.brickset.com/sets/small/80109-1...
# imageURL          https://images.brickset.com/sets/images/80109-...
# ...

# %% [markdown]
# # строки с 1 по 3, столбцы с 1 по 2

# %%
slice_obj = slice(1, 4)
print(df.iloc[slice_obj, 1:3])
# Out:
#              name  year
# 6254  Sandcrawler  2005
# 6407     Baby Zoo  2006
# 6445      Slave I  2006

# %% [markdown]
# # Фильтрация по столбцу year и значению больше 2005

# %%
df[df['year'] > 2005]
# Out:
#         set_id                         name  year       theme  \
# 6407    4962-1                     Baby Zoo  2006       Duplo
# 6445    6209-1                      Slave I  2006   Star Wars
# 6447    6211-1      Imperial Star Destroyer  2006   Star Wars
# 6492    7700-1               Stealth Hunter  2006   Exo-Force
# 6499    7707-1               Striking Venom  2006   Exo-Force
# ...        ...                          ...   ...         ...
# 18025  80037-1           Dragon of the East  2022  Monkie Kid
# 18026  80038-1        Monkie Kid's Team Van  2022  Monkie Kid
# 18027  80039-1          The Heavenly Realms  2022  Monkie Kid
# 18028  80108-1    Lunar New Year Traditions  2022    Seasonal
# 18029  80109-1  Lunar New Year Ice Festival  2022    Seasonal
#
#                             subtheme        themeGroup category  pieces  \
# 6407                      LEGO Ville        Pre-school   Normal    18.0
# 6445                       Episode V          Licensed   Normal   537.0
# ...

# %% [markdown]
# # Фильтрация по столбцу name и значению 'Baby Zoo'

# %%
df[df['name'] == 'Baby Zoo']
# Out:
#       set_id      name  year  theme    subtheme  themeGroup category  pieces  \
# 6407  4962-1  Baby Zoo  2006  Duplo  LEGO Ville  Pre-school   Normal    18.0
#
#       minifigs  agerange_min  US_retailPrice  \
# 6407       1.0           2.0            9.99
#
#                            bricksetURL  \
# 6407  https://brickset.com/sets/4962-1
#
#                                            thumbnailURL  \
# 6407  https://images.brickset.com/sets/small/4962-1.jpg
#
#                                                imageURL
# 6407  https://images.brickset.com/sets/images/4962-1...

# %% [markdown]
# # Сортировка по столбцу year в обратном порядке

# %%
df.sort_values(by='year')
# Out:
#         set_id                         name  year      theme  \
# 6107    7236-1                   Police Car  2005       City
# 6254   10144-1                  Sandcrawler  2005  Star Wars
# 6633   10176-1                King's Castle  2006     Castle
# 6604    8893-1            Lava Chamber Gate  2006   Bionicle
# 6556    8624-1    Race for the Mask of Life  2006   Bionicle
# ...        ...                          ...   ...        ...
# 17766  60316-1               Police Station  2022       City
# 17767  60317-1     Police Chase at the Bank  2022       City
# 17768  60318-1              Fire Helicopter  2022       City
# 17800  60351-1         Rocket Launch Center  2022       City
# 18029  80109-1  Lunar New Year Ice Festival  2022   Seasonal
#
#                             subtheme     themeGroup category  pieces  \
# 6107                          Police     Modern day   Normal    59.0
# 6254                      Episode IV       Licensed   Normal  1669.0
# ...

# %% [markdown]
# # Сортировка по столбцам year и US_retailPrice в обратном порядке

# %%
df.sort_values(by=['agerange_min', 'US_retailPrice'], ascending=[True, False])
# Out:
#         set_id                                  name  year      theme  \
# 8874    5947-1               Winnie the Pooh's House  2011      Duplo
# 8873    5946-1                   Tigger's Expedition  2011      Duplo
# 10076  10558-1                          Number Train  2013      Duplo
# 7763    5592-1                        My First Plane  2009      Duplo
# 8257    5646-1                          Farm Nursery  2010      Duplo
# ...        ...                                   ...   ...        ...
# 18017  76989-1      Horizon Forbidden West: Tallneck  2022      Icons
# 16623  21328-1                              Seinfeld  2021      Ideas
# 17571  21331-1  Sonic the Hedgehog - Green Hill Zone  2022      Ideas
# 17030  75296-1        Darth Vader Meditation Chamber  2021  Star Wars
# 16727  40516-1                   Everyone is Awesome  2021      Icons
#
#               subtheme     themeGroup category  pieces  minifigs  \
# ...

# %% [markdown]
# # Фильтрация по столбцу name и значениям 'My First Plane' и 'Number Train'

# %%
categories = ['My First Plane', 'Number Train']
df[df['name'].isin(categories)]
# Out:
#         set_id            name  year  theme    subtheme  themeGroup category  \
# 7763    5592-1  My First Plane  2009  Duplo  LEGO Ville  Pre-school   Normal
# 10076  10558-1    Number Train  2013  Duplo      Trains  Pre-school   Normal
#
#        pieces  minifigs  agerange_min  US_retailPrice  \
# 7763      8.0       2.0           1.0           14.99
# 10076    31.0       1.0           1.0           19.99
#
#                              bricksetURL  \
# 7763    https://brickset.com/sets/5592-1
# 10076  https://brickset.com/sets/10558-1
#
#                                             thumbnailURL  \
# 7763   https://images.brickset.com/sets/small/5592-1.jpg
# 10076  https://images.brickset.com/sets/small/10558-1...
#
#                                                 imageURL
# 7763   https://images.brickset.com/sets/images/5592-1...
# 10076  https://images.brickset.com/sets/images/10558-...

# %%
df.describe()
# Out:
#               year       pieces     minifigs  agerange_min  US_retailPrice
# count  2669.000000  2669.000000  2669.000000   2669.000000     2669.000000
# mean   2015.886849   405.224429     3.256276      6.671038       46.473095
# std       3.978664   595.524307     2.617888      2.663483       59.569914
# min    2005.000000     4.000000     1.000000      1.000000        1.990000
# 25%    2013.000000    85.000000     1.000000      5.000000       14.990000
# 50%    2016.000000   231.000000     3.000000      6.000000       29.990000
# 75%    2019.000000   493.000000     4.000000      8.000000       49.990000
# max    2022.000000  7541.000000    27.000000     18.000000      849.990000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2669 entries, 6107 to 18029
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   set_id          2669 non-null   object
#  1   name            2669 non-null   object
#  2   year            2669 non-null   int64
#  3   theme           2669 non-null   object
#  4   subtheme        2669 non-null   object
#  5   themeGroup      2669 non-null   object
#  6   category        2669 non-null   object
#  7   pieces          2669 non-null   float64
#  8   minifigs        2669 non-null   float64
#  9   agerange_min    2669 non-null   float64
#  10  US_retailPrice  2669 non-null   float64
#  11  bricksetURL     2669 non-null   object
#  12  thumbnailURL    2669 non-null   object
#  13  imageURL        2669 non-null   object
# dtypes: float64(4), int64(1), object(9)
# memory usage: 377.3+ KB

# %% [markdown]
# # Частота уникальных значений в столбце year

# %%
df['year'].value_counts()
# Out:
# year
# 2016    233
# 2021    227
# 2020    225
# 2017    219
# 2015    218
# 2022    208
# 2014    205
# 2011    178
# 2013    177
# 2018    177
# 2012    174
# 2019    155
# 2010    135
# 2009     93
# 2006     20
# 2008     12
# 2007     11
# 2005      2
# Name: count, dtype: int64

# %% [markdown]
# # Среднее значение year для каждого theme

# %%
df.groupby('theme')['year'].mean()
# Out:
# theme
# Advanced models                 2009.666667
# Avatar                          2022.000000
# Bionicle                        2006.000000
# Books                           2012.750000
# Cars                            2011.400000
# Castle                          2009.695652
# City                            2015.917241
# Classic                         2018.000000
# Collectable Minifigures         2011.815534
# Creator                         2017.431373
# Creator Expert                  2016.142857
# DC Comics Super Heroes          2016.507692
# Dimensions                      2015.758621
# Disney                          2019.131579
# Duplo                           2013.160256
# Education                       2017.000000
# Exo-Force                       2006.000000
# Factory                         2008.000000
# Friends                         2017.374517
# Games                           2010.545455
# Ghostbusters                    2016.000000
# ...
